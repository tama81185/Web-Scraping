# %%
# !pip install requests beautifulsoup4
# optional (better HTML parsing):
# !pip install lxml

# %%
import requests
url= "https://bdjobs.com/"
r=requests.get(url)
print(r.status_code)

# %%
print(r.text)

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text,"lxml")
print(soup)

# %%
print(soup.div)

# %%
# Get the <title> tag
print(soup.title)

# Get tag name
print(soup.title.name)

# Get inner text
print(soup.title.text)

# %%
#find() – returns the first matching element
soup.find("h1")
soup.find("div", class_="post")
soup.find("a", href=True)

# %%
soup.find_all("a")
soup.find_all("div", id="post1")

# %% [markdown]
# **Attributes in HTML**

# %%
url="https://www.wscubetech.com/"
r=requests.get(url)
soup=BeautifulSoup(r.text,"lxml")
#print(soup.div.p)
tag= soup.header
#print(tag.attrs)
print(tag.attrs["class"])

# %% [markdown]
# **Navigable Strings in Html**

# %%
tag=soup.header.div.button
print(tag.string)

# %% [markdown]
# **BeautifulSoup - find() Function **

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.amazon.com/Quilting-Squares-Multi-Color-Scrapbooking-Patchwork/dp/B093BQ3GMM/ref=pd_sim_d_sccl_3_3/147-8021284-0538212?pd_rd_w=M64rU&content-id=amzn1.sym.fc475966-e837-48fc-9ed0-f4ca6ae9337b&pf_rd_p=fc475966-e837-48fc-9ed0-f4ca6ae9337b&pf_rd_r=EGCWXMY4TH5C3Q80XQCH&pd_rd_wg=q7RAL&pd_rd_r=d002c04f-bf14-42c5-bebf-cfc9d92511fa&pd_rd_i=B093BQ3GMM&th=1"
r=requests.get(url)
soup=BeautifulSoup(r.text,"lxml")

# %%
#Basic Page Access
soup                            # Entire HTML document
soup.prettify()                 # Beautified formatted HTML
soup.title                      # Title of the HTML document

# %%
soup.title                      # <title> tag
soup.title.text                 # Text inside title
soup.head                       # <head> section
soup.body                       # <body> section

# %%
#find one element
soup.find("h1")                 # First <h1> tag
soup.find("div")                # First <div>
soup.find("div", class_="a")    # First <div class="a">

# %%
#find one element with attributes
soup.find("div", class_="box")  # <div class="box">
soup.find("a", href=True)       # First link with href

# %%
soup.find("h1")

# %%
#print(soup.find("span",{"class":"a-price-whole"}))
price=soup.find("span",{"class":"a-price-whole"})
print(price.string)

# %%
description=soup.find("h2",{"class":"a-carousel-heading a-inline-block"})
print(description.string)

# %%
a=soup.find("span",class_ ="a-size-mini a-color-base")
if a:
    print(a.string)
else:
    print("Element with class 'a-size-mini a-color-base' not found.")

# %% [markdown]
# **BeautifulSoup - findall() Function with Tags and Attributes**

# %%
#Find MULTIPLE Elements (find_all)

# %%
soup.find_all("p")              # All <p> tags
soup.find_all("a", class_="nav")

# %%
soup.find_all("div", class_="item") #by class

# %%
soup.find_all("a", target="_blank") #by attribute

# %%
soup.find_all("div", class_=["a", "b"]) #by multiple classes

# %%
#limit results
soup.find_all("div", limit=3)   # First 3 divs

# %%
soup("a")                       # Same as find_all("a")

# %% [markdown]
# **CSS Selectors (select)**

# %%
soup.select("div")

# %%
soup.select("div")              # All divs
soup.select(".price")           # Class selector
soup.select("#main")            # ID selector
soup.select("ul li")            # Nested tags
soup.select("a[href]")          # Tags with attribute

# %%
soup.select_one(".title")

# %%
#Extract text
tag.text                        # Raw text
tag.get_text()                  # Clean text
tag.get_text(strip=True)        # Trim whitespace

# %%
#Extract Attributes
tag['href']                     # Direct attribute access
tag.get("href")                 # Safe access
tag.attrs                       # All attributes as dict

# %%
for link in soup.find_all("a"):
    print(link.get("href"))

# %%
#Comments in HTML
rom bs4 import Comment

comments = soup.find_all(string=lambda t: isinstance(t, Comment))

# %%
import re

soup.find_all("a", href=re.compile("product"))

# %%
#Handling Missing Data
price = product.find("span", class_="price")
if price:
    price = price.text
else:
    price = "Not Available"

# %%
#Converting Scraped Data to DataFrame
import pandas as pd

data = []
for p in products:
    data.append({
        "name": p.find("h2").text,
        "price": p.find("span", class_="price").text
    })

df = pd.DataFrame(data)

# %%
from bs4 import BeautifulSoup as bs
r = requests.get("https://keithgalli.github.io/web-scraping/example.html")

# Convert to a beautiful soup object
soup = bs(r.content)


print(soup.prettify())

# %%
first_header = soup.find("h2")

headers = soup.find_all("h2")
print(headers)

# %%
# Pass in a list of elements to look for
first_header = soup.find(["h1", "h2"])

headers = soup.find_all(["h1", "h2"])
headers

# %%
# pass in attributes to the find/find_all function
paragraph = soup.find_all("p", attrs={"id": "paragraph-id"})
paragraph

# %%
#  nest find/find_all calls
body = soup.find('body')
div = body.find('div')
header = div.find('h1')
header

# %%
# We can search specific strings in our find/find_all calls
import re

paragraphs = soup.find_all("p", string=re.compile("Some"))
paragraphs

headers = soup.find_all("h2", string=re.compile("(H|h)eader"))
headers

# %% [markdown]
# **css selector**

# %%
print(soup.body.prettify())

# %%
content = soup.select("div p")
content

# %%
paragraphs = soup.select("h2 ~ p")
paragraphs

# %%
bold_text = soup.select("p#paragraph-id b")
bold_text

# %%
paragraphs = soup.select("body > p")
print(paragraphs)

for paragraph in paragraphs:
  print(paragraph.select("i"))

# %%
# Grab by element with specific property
soup.select("[align=middle]")

# %%
# use .string
header = soup.find("h2")
header.string

# If multiple child elements use get_text
div = soup.find("div")
print(div.prettify())
print(div.get_text())

# %%
# Get a specific property from an element
link = soup.find("a")
link['href']

paragraphs = soup.select("p#paragraph-id")
paragraphs[0]['id']

# %%
# Path Syntax
print(soup.body.prettify())

# %%
# Know the terms: Parent, Sibling, Child

soup.body.find("div").find_next_siblings()

# %%
# Load the webpage content
r = requests.get("https://keithgalli.github.io/web-scraping/webpage.html")

# Convert to a beautiful soup object
webpage = bs(r.content)

# Print out our html
print(webpage.prettify())

# %%
links = webpage.select("ul.socials a")
actual_links = [link['href'] for link in links]
actual_links

# %%
ulist = webpage.find("ul", attrs={"class": "socials"})
links = ulist.find_all("a")
actual_links = [link['href'] for link in links]
actual_links

# %%
links = webpage.select("li.social a")
actual_links = [link['href'] for link in links]
actual_links

# %%
links = webpage.select("body ul li.social a")
links

# %%
header = webpage.body.find("h2", string="Photos")
previous_elements = header.find_previous_siblings()
previous_elements_sorted = previous_elements[::-1]
elements = [x.get_text() for x in previous_elements_sorted]
text = "\n".join(elements)
print(text)

# %%
l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
pd.DataFrame(l, columns=["A", "B", ...])

# %%
import pandas as pd

table = webpage.select("table.hockey-stats")[0]
columns = table.find("thead").find_all("th")
column_names = [c.string for c in columns]

table_rows = table.find("tbody").find_all("tr")
l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [str(tr.get_text()).strip() for tr in td]
    l.append(row)

df = pd.DataFrame(l, columns=column_names)
df.head()

# %%
import re

facts = webpage.select("ul.fun-facts li")
facts_with_is = [fact.find(string=re.compile("is")) for fact in facts]
facts_with_is = [fact.find_parent().get_text() for fact in facts_with_is if fact]
facts_with_is

# %%
# Done locally, but here is the code
import requests # pip install requests
from bs4 import BeautifulSoup as bs # pip install beautifulsoup4

# Load the webpage content
url = "https://keithgalli.github.io/web-scraping/"
r = requests.get(url+"webpage.html")

# Convert to a beautiful soup object
webpage = bs(r.content)

images = webpage.select("div.row div.column img")
image_url = images[0]['src']
full_url = url + image_url

img_data = requests.get(full_url).content
with open('lake_como.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
files = webpage.select("div.block a")
relative_files = [f['href'] for f in files]


url = "https://keithgalli.github.io/web-scraping/"
for f in relative_files:
  full_url = url + f
  page = requests.get(full_url)
  bs_page = bs(page.content)
  secret_word_element = bs_page.find("p", attrs={"id": "secret-word"})
  secret_word = secret_word_element.string
  print(secret_word)
